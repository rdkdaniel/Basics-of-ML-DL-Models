# %% [markdown]
# <a href="https://colab.research.google.com/github/rdkdaniel/Basics-of-ML-DL-Models/blob/main/Pharma_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Getting Data**

# %%
#Connecting colab with kaggle to get the data
#Install the Kaggle library
# !pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Make a directory named “.kaggle”
! mkdir ~/.kaggle

# %%
#Copy the “kaggle.json” into this new directory
! cp kaggle.json ~/.kaggle/

# %%
#Allocate the required permission for this file
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download milanzdravkovic/pharma-sales-data
# Out:
# ...
#   0% 0.00/352k [00:00<?, ?B/s]
# 100% 352k/352k [00:00<00:00, 122MB/s]

# %% [markdown]
# **Unzipping dataset**

# %%
# !unzip pharma-sales-data.zip
# Out:
# Archive:  pharma-sales-data.zip
#   inflating: salesdaily.csv
#   inflating: saleshourly.csv
#   inflating: salesmonthly.csv
#   inflating: salesweekly.csv

# %% [markdown]
# **View datasets**

# %%
#Libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('salesdaily.csv')
df1 = pd.read_csv('saleshourly.csv')
df2 = pd.read_csv('salesmonthly.csv')
df3 = pd.read_csv('salesweekly.csv')

# %%
df.head()
df1.head()
df2.head()
df3.head()
# Out:
#        datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0   1/5/2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  1/12/2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2  1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3  1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4   2/2/2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
df1.head()
# Out:
#             datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C  R03  R06  Year  \
# 0   1/2/2014 8:00    0.0   0.67    0.4    2.0   0.0   0.0  0.0  1.0  2014
# 1   1/2/2014 9:00    0.0   0.00    1.0    0.0   2.0   0.0  0.0  0.0  2014
# 2  1/2/2014 10:00    0.0   0.00    0.0    3.0   2.0   0.0  0.0  0.0  2014
# 3  1/2/2014 11:00    0.0   0.00    0.0    2.0   1.0   0.0  0.0  0.0  2014
# 4  1/2/2014 12:00    0.0   2.00    0.0    5.0   2.0   0.0  0.0  0.0  2014
#
#    Month  Hour Weekday Name
# 0      1     8     Thursday
# 1      1     9     Thursday
# 2      1    10     Thursday
# 3      1    11     Thursday
# 4      1    12     Thursday

# %%
df2.head()
# Out:
#         datum   M01AB    M01AE    N02BA     N02BE   N05B  N05C    R03    R06
# 0  2014-01-31  127.69   99.090  152.100   878.030  354.0  50.0  112.0   48.2
# 1  2014-02-28  133.32  126.050  177.000  1001.900  347.0  31.0  122.0   36.2
# 2  2014-03-31  137.44   92.950  147.655   779.275  232.0  20.0  112.0   85.4
# 3  2014-04-30  113.10   89.475  130.900   698.500  209.0  18.0   97.0   73.7
# 4  2014-05-31  101.79  119.933  132.100   628.780  270.0  23.0  107.0  123.7

# %%
df3.head()
# Out:
#        datum  M01AB  M01AE  N02BA   N02BE  N05B  N05C   R03   R06
# 0   1/5/2014  14.00  11.67   21.3  185.95  41.0   0.0  32.0   7.0
# 1  1/12/2014  29.33  12.68   37.9  190.70  88.0   5.0  21.0   7.2
# 2  1/19/2014  30.67  26.34   45.9  218.40  80.0   8.0  29.0  12.0
# 3  1/26/2014  34.00  32.37   31.5  179.60  80.0   8.0  23.0  10.0
# 4   2/2/2014  31.02  23.35   20.7  159.88  84.0  12.0  29.0  12.0

# %%
df.describe()
# Out:
#              M01AB        M01AE        N02BA        N02BE         N05B  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      5.033683     3.895830     3.880441    29.917095     8.853627
# std       2.737579     2.133337     2.384010    15.590966     5.605605
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.340000     2.000000    19.000000     5.000000
# 50%       4.990000     3.670000     3.500000    26.900000     8.000000
# 75%       6.670000     5.138000     5.200000    38.300000    12.000000
# max      17.340000    14.463000    16.000000   161.000000    54.833333
#
#               N05C          R03          R06         Year        Month  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      0.593522     5.512262     2.900198  2016.401235     6.344255
# std       1.092988     6.428736     2.415816     1.665060     3.386954
# ...

# %% [markdown]
# # **Getting Data 2**

# %% [markdown]
# **Another dataset**

# %%
# !kaggle datasets download vencerlanz09/pharmaceutical-drugs-and-vitamins-synthetic-images
# Out:
# ...
#  97% 230M/238M [00:03<00:00, 99.4MB/s]
# 100% 238M/238M [00:03<00:00, 74.0MB/s]

# %% [markdown]
# **Unzip dataset**

# %%
# !unzip pharmaceutical-drugs-and-vitamins-synthetic-images.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005001.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005002.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005003.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005004.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005005.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005006.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005007.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005008.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005009.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005010.jpg
#   inflating: ImageClassesCombinedWithCOCOAnnotations/images_raw/00005011.jpg
# ...

# %% [markdown]
# # **Engaging the Data**

# %% [markdown]
# **Define data path**

# %%
train_path="/content/Drug Vision/Data Combined"
data_dir_train = pathlib.Path(train_path)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
# Out:
# 10000

# %% [markdown]
# **Data Prep**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Train Data Set Creation**

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='training',
    interpolation='bilinear', follow_links=False, smart_resize=False
)
# Out:
# Found 10000 files belonging to 10 classes.
# Using 8000 files for training.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Alaxan', 'Bactidol', 'Bioflu', 'Biogesic', 'DayZinc', 'Decolgen', 'Fish Oil', 'Kremil S', 'Medicol', 'Neozep']

# %% [markdown]
# **Visualizing this massive dataset**

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from glob import glob
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D

# %%
import matplotlib.pyplot as plt
num=0
for dirpath, dirnames, filenames in os.walk(str(train_path)):
    for filename in [f for f in filenames if f.endswith(".jpg")][:1]:
        img = PIL.Image.open(str(dirpath)+"/"+str(filename))
        plt.subplot(4,4,num+1) #plot for rows and columns adjusted
        plt.title(str(dirpath).split('/')[-1])
        plt.axis('off')
        plt.imshow(img)
        num=num+1

# %% [markdown]
# # **Split the data to training and test 1**

# %% [markdown]
# ***S1. Stanford (Ng & Katanforoosh) technique***: https://cs230.stanford.edu/blog/split/

# %%
filenames = ['/content/Drug Vision/Data Combined']

# %% [markdown]
# I just need train and test sets, so I will ignore the third split item

# %%
split_1 = int(0.8 * len(filenames))
split_2 = int(0.2 * len(filenames))
train_filenames = filenames[:split_1]
test_filenames = filenames[split_2:]

# %% [markdown]
# **S1. Visualize the dataset**

# %%
import matplotlib.pyplot as plt
num=0
for dirpath, dirnames, filenames in os.walk(str(train_filenames)):
    for filename in [f for f in filenames if f.endswith(".jpg")][:1]:
        img = PIL.Image.open(str(dirpath)+"/"+str(filename))
        plt.subplot(4,4,num+1)
        plt.title(str(dirpath).split('/')[-1])
        plt.axis('off')
        plt.imshow(img)
        num=num+1

#WHere are the images???

# %% [markdown]
# **S1. Data Prep**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **S1. Models**

# %%
model=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),         
    
    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),
    
    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),   
    Dense(9, activation='softmax')
])

# %% [markdown]
# ***S2. Gupta through Kaggle technique***: https://www.kaggle.com/questions-and-answers/102677

# %% [markdown]
# # **Split the data to training and test 2**

# %% [markdown]
# **Use the python library split-folder & other methods:** https://stackoverflow.com/questions/53074712/how-to-split-folder-of-images-into-test-training-validation-sets-with-stratified

# %%
pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import splitfolders
splitfolders.ratio('/content/Drug Vision/Data Combined', output="output", seed=1337, ratio=(.8, 0.1,0.1)) 
#Note to self - you must specify the actual path of the data, not just the name of the folder
# Out:
# Copying files: 10000 files [00:02, 4964.85 files/s]

# %% [markdown]
# Output folders
#
# ![012.PNG](data:image/png;base64,...)

# %% [markdown]
# **Define path for train and test images**

# %%
train_path="/content/output/train"
test_path="/content/output/test"
data_dir_train = pathlib.Path(train_path)
data_dir_test = pathlib.Path(test_path)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 8000
# 1000

# %% [markdown]
# **Data Prep**

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# **Train Data Set Creation**

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='training',
    interpolation='bilinear', follow_links=False, smart_resize=False
)
# Out:
# Found 8000 files belonging to 10 classes.
# Using 6400 files for training.

# %% [markdown]
# **Validation Data Set Creation**

# %% [markdown]
# **Note to self:**
#
# *   in Train Data Set Creation, we used a bit of the available data in the train folder for training (6400/8000)
# *   The remaining, will be used for validation.
# *   Remember, in our folder split way above, we created a validation folder that has data fro that - i.e. validation.
# *   We can use it later.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train, labels='inferred', label_mode='categorical',
    class_names=None, color_mode='rgb', batch_size=32, image_size=(180,
    180), shuffle=True, seed=123, validation_split=0.2, subset='validation',
    interpolation='bilinear', follow_links=False, smart_resize=False
)
# Out:
# Found 8000 files belonging to 10 classes.
# Using 1600 files for validation.

# %% [markdown]
# ***Seeeeee above. Now the remaining 1600/8000 is being used for validation***

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Alaxan', 'Bactidol', 'Bioflu', 'Biogesic', 'DayZinc', 'Decolgen', 'Fish Oil', 'Kremil S', 'Medicol', 'Neozep']

# %% [markdown]
# **Visualize the data**

# %%
import matplotlib.pyplot as plt
num=0
for dirpath, dirnames, filenames in os.walk(str(train_path)):
    for filename in [f for f in filenames if f.endswith(".jpg")][:1]:
        img = PIL.Image.open(str(dirpath)+"/"+str(filename))
        plt.subplot(4,4,num+1)
        plt.title(str(dirpath).split('/')[-1])
        plt.axis('off')
        plt.imshow(img)
        num=num+1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# **Let's train some models mahn!!**

# %% [markdown]
# *We shall use the best model from last computer vision experiments, with the optimal epochs.*

# %% [markdown]
# **The Model**

# %%
model_update=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),         
                             
    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Conv2D(64,(3,3),activation='relu',padding='same'),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Conv2D(128,(3,3),activation='relu',padding='same'),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),
    
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.25),   
    Dense(9, activation='softmax')
])

# %% [markdown]
# **Compiling the model**

# %%
model_update.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics='accuracy')

# %% [markdown]
# **Training the model**

# %%
epochs = 10 #what of 10 epochs
history = model_update.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-57cbc9d33067> in <module>
#       3   train_ds,
#       4   validation_data=val_ds,
# ----> 5   epochs=epochs
#       6 )
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ...

# %% [markdown]
# My error is from the design of the model. Let's see model summary
#
# https://stackoverflow.com/questions/73383268/i-am-getting-error-like-input-1-of-layer-model-5-is-incompatible-with-the-lay

# %%
model_update.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 32)      896
#
#  conv2d_3 (Conv2D)           (None, 178, 178, 32)      9248
#
#  max_pooling2d_2 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  dropout_3 (Dropout)         (None, 89, 89, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 89, 89, 64)        18496
#
#  conv2d_5 (Conv2D)           (None, 87, 87, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 43, 43, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 43, 43, 128)       73856
#
#  conv2d_7 (Conv2D)           (None, 41, 41, 128)       147584
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout_5 (Dropout)         (None, 20, 20, 128)       0
#
# ...
